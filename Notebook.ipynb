# %%
import pandas as pd
from PIL import Image
import os
import matplotlib.pyplot as plt
import seaborn as sns

from utils import PlotData

# %%
plot_data = PlotData()
df = pd.read_json("deviation.json")
plot_data.check_missing_values(data=df)
# Out:
# name            0
# gt_corners      0
# rb_corners      0
# mean            0
# max             0
# min             0
# floor_mean      0
# floor_max       0
# floor_min       0
# ceiling_mean    0
# ceiling_max     0
# ceiling_min     0
# dtype: int64

# %%
plot_data.draw_plots("deviation.json")

# %%
path = './plots/'
name = 'bars.png'
filename = os.path.join(path, name)

# %%
img = Image.open(filename)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x500>

# %%
y_t = df["gt_corners"].to_numpy()
y_p = df["rb_corners"].to_numpy()
print(f"r2_score: {plot_data.r2_score(y_true=y_t, y_pred=y_p)}")
print(f"accuracy: {plot_data.accuracy(y_true=y_t, y_pred=y_p)}")
# Out:
# r2_score: 1.0
# accuracy: 1.0

# %% [markdown]
# Показания r2_score и accuracy также указывают на практически идеальную работу модели.

# %%
df.describe()
# Out:
#         gt_corners   rb_corners         mean          max          min  \
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000
# mean      4.307350     4.307350    12.895320    25.448011     2.920388
# std       0.814412     0.814412    21.839948    42.758159     9.258972
# min       4.000000     4.000000     0.192973     0.323886     0.007456
# 25%       4.000000     4.000000     0.658488     1.243804     0.147432
# 50%       4.000000     4.000000     2.123456     4.703514     0.279876
# 75%       4.000000     4.000000    14.810982    28.312051     0.674444
# max      10.000000    10.000000   121.301055   179.165483    81.764483
#
#         floor_mean    floor_max    floor_min  ceiling_mean  ceiling_max  \
# count  1347.000000  1347.000000  1347.000000   1347.000000  1347.000000
# mean     11.022443    20.405499     3.146246     14.768198    24.848020
# std      19.136320    33.189081     9.559611     26.047057    42.345579
# ...
